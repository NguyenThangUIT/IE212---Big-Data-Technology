# %%
from kafka import KafkaConsumer
from pymongo import MongoClient
import json

# Kafka configuration
KAFKA_TOPIC = "vnexpress_rss"
KAFKA_BOOTSTRAP_SERVERS = "localhost:9092"

# MongoDB configuration
MONGO_URI = "mongodb://localhost:27017/"
MONGO_DB = "vnexpress"
MONGO_COLLECTION = "article"

def save_to_mongodb(article):
    # Lưu bài viết vào MongoDB, tránh trùng lặp dựa trên tiêu đề.
    try:
        # Kết nối MongoDB
        client = MongoClient(MONGO_URI)
        db = client[MONGO_DB]
        collection = db[MONGO_COLLECTION]
        
        # Kiểm tra trùng lặp bài viết dựa trên tiêu đề
        if collection.find_one({"title": article["title"]}):
            print(f"Bài báo '{article['title']}' đã tồn tại.")
        else:
            # Thêm bài viết vào MongoDB
            collection.insert_one(article)
            print(f"Bài báo '{article['title']}' đã được thêm.")
    except Exception as e:
        print(f"Error saving to MongoDB: {e}")
    finally:
        client.close()

if __name__ == "__main__":
    # Kết nối Kafka
    consumer = KafkaConsumer(
        KAFKA_TOPIC,
        bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
        auto_offset_reset="earliest",
        enable_auto_commit=True,
        group_id="vnexpress_group",
        value_deserializer=lambda v: json.loads(v.decode("utf-8"))
    )
    
    print("Consumer started. Waiting for messages...")
    for message in consumer:
        article = message.value
        
        # Lưu bài viết vào MongoDB
        save_to_mongodb(article)
# Out:
# Consumer started. Waiting for messages...
# Bài báo 'Nhân tài được vay ưu đãi mua nhà trả góp' đã được thêm.
# Bài báo ''Mở cửa' cho tích tụ đất đai trong nông nghiệp' đã được thêm.
# Bài báo 'Biển người ở trung tâm Hà Nội, TP HCM đón năm mới' đã được thêm.
# Bài báo 'Tổng rà soát chất lượng cán bộ, công chức, viên chức' đã được thêm.
# Bài báo 'Đề xuất chính sách đặc thù cho dự án điện hạt nhân Ninh Thuận' đã được thêm.
# Bài báo 'Cấm xe 20 đường trung tâm TP HCM để bắn pháo hoa' đã được thêm.
# Bài báo 'Metro chạy xuyên đêm chở khách đón Tết Dương lịch' đã được thêm.
# Bài báo 'Ôtô tông vào rạp đám tang dựng dưới lòng đường' đã được thêm.
# Bài báo '68 cán bộ diện Trung ương quản lý bị kỷ luật trong năm 2024' đã được thêm.
# Bài báo 'Học viện Chính trị quốc gia Hồ Chí Minh giảm 23 đầu mối' đã được thêm.
# Bài báo 'Bạc Liêu đầu tư 1.450 tỷ đồng làm đường vành đai' đã được thêm.
# Bài báo 'Tàu chở 4 thuyền viên mất tích trên biển' đã được thêm.
# Bài báo 'Phát hiện dấu tích thành cổ Hoa Lư khi đào móng nhà' đã được thêm.
# Bài báo 'Sập giàn giáo công trình thủy điện, 3 người chết' đã được thêm.
# Bài báo 'Nữ nhân viên đường sắt bị đánh gãy xương mũi vì 'không mở gác chắn tàu'' đã được thêm.
# Bài báo 'Nâng tĩnh không hai cầu cửa ngõ TP HCM' đã được thêm.
# Bài báo 'Mặn đến sớm, nhà vườn miền Tây không kịp trở tay' đã được thêm.
# Bài báo 'Ôtô lao xuống sông, hai người chết' đã được thêm.
# Bài báo 'Hà Nội phát sinh 16 điểm ùn tắc' đã được thêm.
# Bài báo 'Đồng Nai chọn phương án xây cầu Cát Lái 19.000 tỷ đồng thay hầm' đã được thêm.
# Bài báo 'Đào Nhật Tân vào vụ Tết' đã được thêm.
# Bài báo 'Tăng cường an toàn bay sau tai nạn máy bay Jeju Air' đã được thêm.
# Bài báo 'Bãi biển 'đẹp nhất châu Á' sạt lở' đã được thêm.
# Bài báo 'Nối thông toàn tuyến cao tốc Bắc Nam, đường Hồ Chí Minh vào năm 2025' đã được thêm.
# Bài báo 'Đại tá Phan Huy Ngọc làm Chủ tịch tỉnh Hà Giang' đã được thêm.
# Bài báo '13 cơ quan trung ương hoàn thành tinh gọn bộ máy' đã được thêm.
# Bài báo 'Khai thác 8 trạm dừng nghỉ tạm trên cao tốc Bắc Nam dịp Tết' đã được thêm.
# Bài báo 'TP HCM đồng loạt khánh thành 4 công trình trọng điểm' đã được thêm.
# Bài báo 'Dự kiến cần 130.000 tỷ đồng giải quyết chế độ khi tinh gọn bộ máy' đã được thêm.
# Bài báo 'Hơn 900.000 lượt khách đi metro Bến Thành - Suối Tiên tuần đầu vận hành' đã được thêm.
# Bài báo 'Hai nhánh hầm chui nút cửa ngõ Nam TP HCM trước lúc thông xe' đã được thêm.
# Bài báo 'Cách đi metro Bến Thành - Suối Tiên từ đầu năm 2025' đã được thêm.
# Bài báo 'Sà lan 245 tấn va chạm thuyền, một người chết' đã được thêm.
# Bài báo 'Thưởng Tết cao nhất ở Hà Nội 311 triệu đồng' đã được thêm.
# Bài báo '50 bệnh nhi được Quỹ Hy vọng tài trợ ghép tạng, tế bào gốc' đã được thêm.
# Bài báo 'Gần 30 tỷ đồng thắp 'ánh sáng học đường'' đã được thêm.
# Bài báo 'Thủ tướng: 'Cái gì doanh nghiệp làm tốt hơn thì Nhà nước không làm'' đã được thêm.
# Bài báo 'Chủ tịch Quốc hội: Huế cần xây dựng bộ máy quản lý chuyên sâu' đã được thêm.
# Bài báo 'Hàng chục xưởng gỗ ở Hà Nội cháy ngùn ngụt' đã được thêm.
# Bài báo 'Sẽ xin ý kiến Bộ Chính trị về chính sách hỗ trợ cán bộ công chức khi tinh gọn bộ máy' đã được thêm.
# Bài báo 'Đông nghịt người đi metro Bến Thành - Suối Tiên cuối tuần' đã được thêm.
# Bài báo 'Miền Bắc sương mù, miền Trung mưa trở lại dịp Tết Dương lịch' đã được thêm.
# Bài báo 'TP HCM khai thác 15 km đoạn trên cao Vành đai 3 vào năm sau' đã được thêm.
# Bài báo 'Thu hoạch chuối bằng hệ thống cáp treo dài hơn 100 km' đã được thêm.
# Bài báo 'Cầu giảm ùn tắc cửa ngõ phía Nam TP HCM trước ngày thông xe' đã được thêm.
# Bài báo 'Chim quý bay lạc vào nhà dân' đã được thêm.
# Bài báo 'Phó chủ nhiệm Văn phòng Chính phủ làm Thứ trưởng Nội vụ' đã được thêm.
# Bài báo 'Đá lớn rơi xuống đường đèo An Khê' đã được thêm.
# Bài báo 'TP HCM muốn giữ lại Sở Du lịch, An toàn thực phẩm khi tinh gọn bộ máy' đã được thêm.
# Bài báo 'Cảnh sát cưa cửa, nâng tường cứu tài xế mắc kẹt' đã được thêm.
# Bài báo 'Nhà ga T3 Tân Sơn Nhất sau một năm thi công' đã được thêm.
# Bài báo 'Bảo tồn 60 ha rừng tràm để 'dụ' ong lấy mật thu tiền tỷ' đã được thêm.
# Bài báo 'Năm 2024 nắng nóng, bão mạnh bất thường' đã được thêm.
# Bài báo 'Cán mốc 400 cầu Hy vọng' đã được thêm.
# Bài báo 'Thủ tướng muốn ngành nông nghiệp xuất khẩu 70 tỷ USD năm 2025' đã được thêm.
# Bài báo 'Nhiều tuyến phố TP HCM ngập trong mưa lớn cuối mùa' đã được thêm.
# Bài báo 'Tàu điện Bến Thành - Suối Tiên dừng chạy do mưa lớn' đã được thêm.
# Bài báo 'Cú điện thoại giúp cảnh sát cứu người trong vụ nhà cháy ở TP HCM' đã được thêm.
# Bài báo 'Máy bay hạ cánh để cấp cứu hành khách' đã được thêm.
# Bài báo 'PGS Đào Duy Quát: Kỷ nguyên mới cần cán bộ sáng tạo và linh hoạt' đã được thêm.
